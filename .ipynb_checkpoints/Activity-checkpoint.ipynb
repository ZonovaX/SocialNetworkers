# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import statsmodels.api as sm

# %% [markdown]
# # Tomi data

# %%
data = pd.read_csv('Tomi_core_tweets.csv')
data
# Out:
#        Is_retweet  Is_quote  Is_reply  Retweets  Favorites  \
# 0           False     False     False       113        602
# 1           False     False     False       284       2488
# 2           False     False     False       753       5081
# 3           False     False     False        89        495
# 4           False     False     False       305       2764
# ...           ...       ...       ...       ...        ...
# 20765       False     False     False         0          0
# 20766       False     False     False         0          0
# 20767       False     False     False         0          0
# 20768        True     False     False         2          0
# 20769       False     False     False         0          0
#
#                    Created   Time_since_last  Streak of 0:30:00  \
# 0      2021-05-28 03:27:25   0 days 00:48:20                  1
# 1      2021-05-28 02:39:05   0 days 01:38:23                  1
# 2      2021-05-28 01:00:42   0 days 00:51:58                  1
# 3      2021-05-28 00:08:44   0 days 00:32:24                  1
# 4      2021-05-27 23:36:20   0 days 03:10:27                  1
# ...                    ...               ...                ...
# 20765  2014-07-19 06:48:49  20 days 10:03:57                  1
# 20766  2014-06-28 20:44:52   7 days 18:16:34                  1
# 20767  2014-06-21 02:28:18   2 days 12:40:46                  1
# 20768  2014-06-18 13:47:32   3 days 11:13:52                  1
# 20769  2014-06-15 02:33:40               NaN                  1
#
#        Streak of 6:00:00  Per 1:00:00  Per 1 day, 0:00:00  Predicted_polarity  \
# 0                      8            1                   8            0.255926
# 1                      8            1                   8           -0.008599
# 2                      8            1                   8           -0.872967
# 3                      8            1                   8            0.206923
# 4                      8            1                   8            0.103586
# ...                  ...          ...                 ...                 ...
# 20765                  1            1                   1           -0.026356
# 20766                  1            1                   1           -0.026356
# 20767                  1            1                   1           -0.351205
# 20768                  1            1                   1            0.915710
# 20769                  1            1                   1            0.408056
#
#             User
# 0      468646961
# 1      468646961
# 2      468646961
# 3      468646961
# 4      468646961
# ...          ...
# 20765   30721022
# 20766   30721022
# 20767   30721022
# 20768   30721022
# 20769   30721022
#
# [20770 rows x 13 columns]

# %%
pd.plotting.scatter_matrix(data[['Retweets','Favorites','Created','Time_since_last','Streak of 0:30:00','Streak of 6:00:00','Per 1:00:00','Per 1 day, 0:00:00','Predicted_polarity']], figsize = (28,28))
plt.show()

# %%
data['thing_squared'] = data['Per 1:00:00']**2
fit = sm.OLS(np.array(data.Predicted_polarity), sm.add_constant(np.array(data[['Per 1:00:00', 'thing_squared']]))).fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     218.8
# Date:                Fri, 28 May 2021   Prob (F-statistic):           9.46e-95
# Time:                        11:05:39   Log-Likelihood:                -10758.
# No. Observations:               20770   AIC:                         2.152e+04
# Df Residuals:                   20767   BIC:                         2.155e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0968      0.004     24.059      0.000       0.089       0.105
# x1            -0.0146      0.001    -15.347      0.000      -0.016      -0.013
# x2             0.0005   2.44e-05     19.644      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        1.159   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.560   Jarque-Bera (JB):                1.178
# Skew:                          -0.010   Prob(JB):                        0.555
# Kurtosis:                       2.969   Cond. No.                         450.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data['Spread'] = (data['Retweets']+1)*(data['Favorites']+1)*data['Predicted_polarity']*(1-data['Is_retweet'])*(1-data['Is_quote'])*(1-data['Is_reply'])
pd.plotting.scatter_matrix(data[['Spread','User']], figsize = (28,28))
# Out:
# array([[<AxesSubplot:xlabel='Spread', ylabel='Spread'>,
#         <AxesSubplot:xlabel='User', ylabel='Spread'>],
#        [<AxesSubplot:xlabel='Spread', ylabel='User'>,
#         <AxesSubplot:xlabel='User', ylabel='User'>]], dtype=object)

# %%
# Out:
# <ufunc 'positive'>

# %% [markdown]
# # Erdős data

# %%
data = pd.read_csv('Erdos_core_tweets.csv')
data
# Out:
#        Is_retweet  Is_quote  Is_reply  Retweets  Favorites  \
# 0            True     False     False         1          0
# 1           False      True     False         0          1
# 2           False     False      True         0          1
# 3           False      True     False         0          4
# 4           False     False      True         1          6
# ...           ...       ...       ...       ...        ...
# 18651       False     False      True         0          0
# 18652       False     False     False         1          3
# 18653       False     False      True         0          2
# 18654       False     False      True         0          2
# 18655       False     False      True         0          1
#
#                    Created   Time_since_last  Streak of 0:30:00  \
# 0      2021-05-20 02:52:07   2 days 12:09:26                  1
# 1      2021-05-17 14:42:41   0 days 00:00:38                  2
# 2      2021-05-17 14:42:03  10 days 14:15:05                  2
# 3      2021-05-07 00:26:58   0 days 00:09:20                  2
# 4      2021-05-07 00:17:38   6 days 12:42:47                  2
# ...                    ...               ...                ...
# 18651  2020-10-03 15:57:07   0 days 00:00:14                  2
# 18652  2020-10-03 15:56:53   0 days 18:09:22                  2
# 18653  2020-10-02 21:47:31   0 days 03:59:29                  1
# 18654  2020-10-02 17:48:02   0 days 01:09:22                  1
# 18655  2020-10-02 16:38:40               NaN                  1
#
#        Streak of 6:00:00  Per 1:00:00  Per 1 day, 0:00:00  Predicted_polarity  \
# 0                      1            1                   1           -0.026356
# 1                      2            2                   2           -0.023730
# 2                      2            2                   2            0.911806
# 3                      2            2                   2           -0.026356
# 4                      2            2                   2           -0.026356
# ...                  ...          ...                 ...                 ...
# 18651                  2            2                   2            0.010908
# 18652                  2            2                   2            0.725753
# 18653                  3            1                   3            0.188250
# 18654                  3            1                   3            0.212042
# 18655                  3            1                   3           -0.008599
#
#                      User
# 0      840727059001417728
# 1      840727059001417728
# 2      840727059001417728
# 3      840727059001417728
# 4      840727059001417728
# ...                   ...
# 18651           556041652
# 18652           556041652
# 18653           556041652
# 18654           556041652
# 18655           556041652
#
# [18656 rows x 13 columns]

# %%
pd.plotting.scatter_matrix(data[['Retweets','Favorites','Created','Time_since_last','Streak of 0:30:00','Streak of 6:00:00','Per 1:00:00','Per 1 day, 0:00:00','Predicted_polarity']], figsize = (28,28))
plt.show()

# %%
data['thing_squared'] = data['Per 1:00:00']**2
fit = sm.OLS(np.array(data.Predicted_polarity), sm.add_constant(np.array(data[['Per 1:00:00']]))).fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     41.10
# Date:                Fri, 28 May 2021   Prob (F-statistic):           1.48e-10
# Time:                        10:55:23   Log-Likelihood:                -9990.0
# No. Observations:               18656   AIC:                         1.998e+04
# Df Residuals:                   18654   BIC:                         2.000e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1178      0.004     32.170      0.000       0.111       0.125
# x1            -0.0045      0.001     -6.411      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                       29.261   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.572
# Skew:                          -0.013   Prob(JB):                     4.62e-06
# Kurtosis:                       2.824   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Chapo data

# %%
data = pd.read_csv('./Messing Around/Chapo_core_tweets.csv')
data
# Out:
#        Is_retweet  Is_quote  Is_reply  Retweets  Favorites  \
# 0            True     False     False        27          0
# 1            True      True     False         2          0
# 2            True     False     False         4          0
# 3            True     False     False         9          0
# 4            True     False     False         7          0
# ...           ...       ...       ...       ...        ...
# 21101       False     False     False         0        111
# 21102        True     False     False      8657          0
# 21103        True     False     False       222          0
# 21104        True     False     False        12          0
# 21105       False     False     False       210       1824
#
#                    Created   Time_since_last  Streak of 0:30:00  \
# 0      2021-05-21 18:11:14  30 days 02:45:53                  1
# 1      2021-04-21 15:25:21   0 days 00:00:13                  2
# 2      2021-04-21 15:25:08  11 days 20:43:03                  2
# 3      2021-04-09 18:42:05   0 days 00:00:22                  2
# 4      2021-04-09 18:41:43  10 days 04:47:27                  2
# ...                    ...               ...                ...
# 21101  2021-05-16 20:15:13   0 days 00:42:54                  6
# 21102  2021-05-16 19:32:19   0 days 00:12:52                  3
# 21103  2021-05-16 19:19:27   0 days 00:00:42                  3
# 21104  2021-05-16 19:18:45   0 days 01:51:28                  3
# 21105  2021-05-16 17:27:17               NaN                  1
#
#        Streak of 6:00:00  Per 1:00:00  Per 1 day, 0:00:00  Predicted_polarity  \
# 0                      1            1                   1           -0.241024
# 1                      2            2                   2           -0.336924
# 2                      2            2                   2            0.770254
# 3                      2            2                   2            0.724588
# 4                      2            2                   2           -0.110707
# ...                  ...          ...                 ...                 ...
# 21101                 21            2                  21           -0.083495
# 21102                 21            3                  20            0.009221
# 21103                 21            3                  20           -0.650277
# 21104                 21            3                  20           -0.023897
# 21105                 21            1                  19            0.124956
#
#                      User
# 0      722127759699505153
# 1      722127759699505153
# 2      722127759699505153
# 3      722127759699505153
# 4      722127759699505153
# ...                   ...
# 21101            10448062
# 21102            10448062
# 21103            10448062
# 21104            10448062
# 21105            10448062
#
# [21106 rows x 13 columns]

# %%
pd.plotting.scatter_matrix(data[['Retweets','Favorites','Created','Time_since_last','Streak of 0:30:00','Streak of 6:00:00','Per 1:00:00','Per 1 day, 0:00:00','Predicted_polarity']], figsize = (28,28))
plt.show()

# %%
data['thing_squared'] = data['Per 1:00:00']**2
fit = sm.OLS(np.array(data.Predicted_polarity), sm.add_constant(np.array(data[['Streak of 0:30:00']]))).fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.647
# Date:                Fri, 28 May 2021   Prob (F-statistic):              0.199
# Time:                        15:44:25   Log-Likelihood:                -10026.
# No. Observations:               21106   AIC:                         2.006e+04
# Df Residuals:                   21104   BIC:                         2.007e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0389      0.003     12.536      0.000       0.033       0.045
# x1            -0.0004      0.000     -1.283      0.199      -0.001       0.000
# ==============================================================================
# Omnibus:                       35.349   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.903
# Skew:                          -0.031   Prob(JB):                     7.96e-10
# Kurtosis:                       3.210   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
